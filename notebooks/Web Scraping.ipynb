# %%
import pandas as pd
import numpy as np

# %%
import requests
import lxml
import bs4
from bs4 import BeautifulSoup

# %%
forbes_table = pd.read_csv('/Users/Julia/labs/Ironhack-Module-1-Project---Pipelines-Julia-Roch-/data/processed/processed_data.csv')
display(forbes_table)
# Out:
#         id    lastName  age (years old)  Unnamed: 0_x gender        country  \
# 0     8760       BEZOS             54.0          52.0   None  United States
# 1     7500       GATES             62.0          53.0      M           None
# 2     5751     bufFETT             87.0          54.0      M           None
# 3     8365     arNAULt             69.0          55.0   None         France
# 4     5328  zUCKERBERg             33.0          56.0   None  United States
# ...    ...         ...              ...           ...    ...            ...
# 2255  1546         NaN              NaN           NaN    NaN            NaN
# 2256  8869         NaN              NaN           NaN    NaN            NaN
# 2257  8722         NaN              NaN           NaN    NaN            NaN
# 2258  4162         NaN              NaN           NaN    NaN            NaN
# 2259  2497         NaN              NaN           NaN    NaN            NaN
#
# ...

# %%
x = forbes_table.loc[forbes_table['country']=='None', 'name'].tolist()
len(x)
# Out:
# 1375

# %%
url = 'https://www.forbes.com/billionaires/list/;#version:static'
html = requests.get(url).content
soup = BeautifulSoup(html, 'lxml')

# %%
table = soup.find_all('table',{'id':'the_list'})
table
# Out:
# []

# %%
rows = table.find_all('tr')
rows_parsed = [row.text for row in rows]
rows_parsed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-3031c6d6b9a9> in <module>
# ----> 1 rows = table.find_all('tr')
#       2 rows_parsed = [row.text for row in rows]
#       3 rows_parsed
#
# ~/miniconda3/envs/jupyter_env/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
