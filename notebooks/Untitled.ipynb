# %%
import pandas as pd
import numpy as np
import sqlalchemy

# %%
from sqlalchemy import create_engine
sqlitedb_path = '/Users/Julia/labs/Ironhack-Module-1-Project---Pipelines-Julia-Roch-/data/raw/juliarochflores.db'
engine = create_engine(f'sqlite:///{sqlitedb_path}')

# %%
engine.table_names()
# Out:
# ['business_info', 'personal_info', 'rank_info']

# %%
business = pd.read_sql_table('business_info', engine)
display(business)
# Out:
#         id  Unnamed: 0                                           Source  \
# 0     8760          52                           Technology  ==> Amazon
# 1     7500          53                        Technology  ==> Microsoft
# 2     5751          54  Finance and Investments  ==> Berkshire Hathaway
# 3     8365          55                       Fashion & Retail  ==> LVMH
# 4     5328          56                         Technology  ==> Facebook
# ...    ...         ...                                              ...
# 2203  4506        2255     Fashion & Retail  ==> fashion, entertainment
# 2204  6986        2256          Manufacturing  ==> electrical equipment
# 2205  1828        2257          Manufacturing  ==> electrical equipment
# 2206  6448        2258        Manufacturing  ==> printed circuit boards
# 2207  1860        2259                     Diversified  ==> diversified
#
#            worth          worthChange  realTimeWorth  realTimePosition
# 0     112.0 BUSD     0.0 millions USD            NaN                 1
# 1      90.0 BUSD  -0.001 millions USD            NaN                 2
# 2      84.0 BUSD  -0.002 millions USD            NaN                 3
# 3      72.0 BUSD     0.0 millions USD            NaN                 4
# 4      71.0 BUSD     0.0 millions USD            NaN                 5
# ...          ...                  ...            ...               ...
# 2203    1.0 BUSD     0.0 millions USD            NaN              2134
# 2204    1.0 BUSD     nan millions USD            NaN              2134
# 2205    1.0 BUSD     0.0 millions USD            NaN              1856
# 2206    1.0 BUSD     0.0 millions USD            NaN              1978
# 2207    1.0 BUSD     nan millions USD            NaN              1978
#
# [2208 rows x 7 columns]

# %%
personal = pd.read_sql_table('personal_info', engine)
display(personal)
# Out:
#         id    lastName           age  Unnamed: 0  gender  \
# 0     8760       BEZOS  54 years old          52    None
# 1     7500       GATES  62 years old          53    Male
# 2     5751     bufFETT  87 years old          54       M
# 3     8365     arNAULt  69 years old          55    None
# 4     5328  zUCKERBERg          1985          56    None
# ...    ...         ...           ...         ...     ...
# 2203  4506        ZHAO  51 years old        2255       M
# 2204  6986        zhOU  55 years old        2256    None
# 2205  1828         zHU  51 years old        2257       M
# 2206  6448        ZHUO  52 years old        2258  Female
# 2207  1860       zoRLu  54 years old        2259       M
#
#                          country  \
# 0                  United States
# 1                           None
# 2                           None
# 3                         France
# 4                  United States
# ...                          ...
# 2203                       China
# 2204                        None
# 2205  People's Republic of China
# 2206                        None
# 2207                      Turkey
#
#                                                   image
# 0     https://specials-images.forbesimg.com/imageser...
# 1     https://specials-images.forbesimg.com/imageser...
# 2     https://specials-images.forbesimg.com/imageser...
# 3     https://specials-images.forbesimg.com/imageser...
# 4     https://specials-images.forbesimg.com/imageser...
# ...                                                 ...
# 2203  https://specials-images.forbesimg.com/imageser...
# 2204  https://specials-images.forbesimg.com/imageser...
# 2205  https://specials-images.forbesimg.com/imageser...
# 2206  https://specials-images.forbesimg.com/imageser...
# 2207  https://specials-images.forbesimg.com/imageser...
#
# [2208 rows x 7 columns]

# %%
rank = pd.read_sql_table('rank_info', engine)
display(rank)
# Out:
#         id                         name  position  Unnamed: 0
# 0     6367  ananT ASAVABHOKHIN & family       NaN           0
# 1     7613               arash FERDOWSI       NaN           1
# 2     6139     banthoon LAMSAM & FAMILY       NaN           2
# 3     5671       bill ADDERLEY & family       NaN           3
# 4     2117            boris zINGArevich       NaN           4
# ...    ...                          ...       ...         ...
# 2255  4506               zhao XIAOQiang    2204.0        2255
# 2256  6986              zHOU LIANgzhang    2205.0        2256
# 2257  1828                 zhu XINGMIng    2206.0        2257
# 2258  6448                     ZHUO JUN    2207.0        2258
# 2259  1860                  olguN ZOrlu    2208.0        2259
#
# [2260 rows x 4 columns]

# %%
business.info()
business.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 7 columns):
# id                  2208 non-null int64
# Unnamed: 0          2208 non-null int64
# Source              2208 non-null object
# worth               2208 non-null object
# worthChange         2208 non-null object
# realTimeWorth       0 non-null float64
# realTimePosition    2208 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 120.9+ KB
# id                     0
# Unnamed: 0             0
# Source                 0
# worth                  0
# worthChange            0
# realTimeWorth       2208
# realTimePosition       0
# dtype: int64

# %%
null_cols_business = business.isnull().sum()
null_cols_business[null_cols_business > 0] / len(business) * 100
# Out:
# realTimeWorth    100.0
# dtype: float64

# %%
personal.info()
personal.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 7 columns):
# id            2208 non-null int64
# lastName      2208 non-null object
# age           2143 non-null object
# Unnamed: 0    2208 non-null int64
# gender        2195 non-null object
# country       2208 non-null object
# image         2208 non-null object
# dtypes: int64(2), object(5)
# memory usage: 120.9+ KB
# id             0
# lastName       0
# age           65
# Unnamed: 0     0
# gender        13
# country        0
# image          0
# dtype: int64

# %%
null_cols_personal = personal.isnull().sum()
null_cols_personal[null_cols_personal > 0] / len(personal) * 100
# Out:
# age       2.943841
# gender    0.588768
# dtype: float64

# %%
rank.info()
rank.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260 entries, 0 to 2259
# Data columns (total 4 columns):
# id            2260 non-null int64
# name          2260 non-null object
# position      2208 non-null float64
# Unnamed: 0    2260 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 70.8+ KB
# id             0
# name           0
# position      52
# Unnamed: 0     0
# dtype: int64

# %%
null_cols_rank = rank.isnull().sum()
null_cols_rank[null_cols_rank > 0] / len(rank) * 100
# Out:
# position    2.300885
# dtype: float64

# %%
#business.drop('realTimeWorth', axis=1, inplace=True)
display(business)
# Out:
#         id  Unnamed: 0                                           Source  \
# 0     8760          52                           Technology  ==> Amazon
# 1     7500          53                        Technology  ==> Microsoft
# 2     5751          54  Finance and Investments  ==> Berkshire Hathaway
# 3     8365          55                       Fashion & Retail  ==> LVMH
# 4     5328          56                         Technology  ==> Facebook
# ...    ...         ...                                              ...
# 2203  4506        2255     Fashion & Retail  ==> fashion, entertainment
# 2204  6986        2256          Manufacturing  ==> electrical equipment
# 2205  1828        2257          Manufacturing  ==> electrical equipment
# 2206  6448        2258        Manufacturing  ==> printed circuit boards
# 2207  1860        2259                     Diversified  ==> diversified
#
#            worth          worthChange  realTimePosition
# 0     112.0 BUSD     0.0 millions USD                 1
# 1      90.0 BUSD  -0.001 millions USD                 2
# 2      84.0 BUSD  -0.002 millions USD                 3
# 3      72.0 BUSD     0.0 millions USD                 4
# 4      71.0 BUSD     0.0 millions USD                 5
# ...          ...                  ...               ...
# 2203    1.0 BUSD     0.0 millions USD              2134
# 2204    1.0 BUSD     nan millions USD              2134
# 2205    1.0 BUSD     0.0 millions USD              1856
# 2206    1.0 BUSD     0.0 millions USD              1978
# 2207    1.0 BUSD     nan millions USD              1978
#
# [2208 rows x 6 columns]

# %%
df_outer = pd.merge(personal, business, on='id', how='outer')
df_outer2 = pd.merge(df_outer, rank, on='id', how='outer')
display(df_outer2)
# Out:
#         id    lastName           age  Unnamed: 0_x gender        country  \
# 0     8760       BEZOS  54 years old          52.0   None  United States
# 1     7500       GATES  62 years old          53.0   Male           None
# 2     5751     bufFETT  87 years old          54.0      M           None
# 3     8365     arNAULt  69 years old          55.0   None         France
# 4     5328  zUCKERBERg          1985          56.0   None  United States
# ...    ...         ...           ...           ...    ...            ...
# 2255  1546         NaN           NaN           NaN    NaN            NaN
# 2256  8869         NaN           NaN           NaN    NaN            NaN
# 2257  8722         NaN           NaN           NaN    NaN            NaN
# 2258  4162         NaN           NaN           NaN    NaN            NaN
# 2259  2497         NaN           NaN           NaN    NaN            NaN
#
#                                                   image  Unnamed: 0_y  \
# 0     https://specials-images.forbesimg.com/imageser...          52.0
# 1     https://specials-images.forbesimg.com/imageser...          53.0
# 2     https://specials-images.forbesimg.com/imageser...          54.0
# 3     https://specials-images.forbesimg.com/imageser...          55.0
# 4     https://specials-images.forbesimg.com/imageser...          56.0
# ...                                                 ...           ...
# 2255                                                NaN           NaN
# 2256                                                NaN           NaN
# 2257                                                NaN           NaN
# 2258                                                NaN           NaN
# 2259                                                NaN           NaN
#
#                                                Source       worth  \
# 0                              Technology  ==> Amazon  112.0 BUSD
# 1                           Technology  ==> Microsoft   90.0 BUSD
# 2     Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3                          Fashion & Retail  ==> LVMH   72.0 BUSD
# 4                            Technology  ==> Facebook   71.0 BUSD
# ...                                               ...         ...
# 2255                                              NaN         NaN
# 2256                                              NaN         NaN
# 2257                                              NaN         NaN
# 2258                                              NaN         NaN
# 2259                                              NaN         NaN
#
#               worthChange  realTimePosition                      name  \
# 0        0.0 millions USD               1.0                jefF BEZOs
# 1     -0.001 millions USD               2.0                bILL GATES
# 2     -0.002 millions USD               3.0            WARREN BUFFEtt
# 3        0.0 millions USD               4.0           bernARD ARNAULT
# 4        0.0 millions USD               5.0           maRK ZUCKERBERG
# ...                   ...               ...                       ...
# 2255                  NaN               NaN  supaluck UMPUJH & family
# 2256                  NaN               NaN               thOMAS duff
# 2257                  NaN               NaN           zakHAR SMUshkin
# 2258                  NaN               NaN  zhaNG ZHONGNENG & FAmily
# 2259                  NaN               NaN                 zHU YICAi
#
#       position  Unnamed: 0
# 0          1.0          52
# 1          2.0          53
# 2          3.0          54
# 3          4.0          55
# 4          5.0          56
# ...        ...         ...
# 2255       NaN          47
# 2256       NaN          48
# 2257       NaN          49
# 2258       NaN          50
# 2259       NaN          51
#
# [2260 rows x 15 columns]
