# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl 
import matplotlib.pyplot as plt

# %%
df_forbes = pd.read_csv('/Users/Julia/labs/Ironhack-Module-1-Project---Pipelines-Julia-Roch-/data/processed/processed_data.csv')
df_wikipedia = pd.read_csv('/Users/Julia/labs/Ironhack-Module-1-Project---Pipelines-Julia-Roch-/data/processed/processed_data_ws.csv')

# %%
df_complete = pd.merge(df_forbes, df_wikipedia, on='country', how='outer')

# %%
df_complete.rename(columns={'name':'number of billionaires'}, inplace=True)
df_complete = df_complete.drop(df_complete.index[0])

# %%
display(df_complete)
# Out:
#                country number of billionaires Rank    Population         Date  \
# 1            Argentina                      3   31  4.493871e+07   1 Jul 2019
# 2            Australia                     12   54  2.557894e+07   9 Jan 2020
# 3              Austria                      2   97  8.898457e+06   1 Oct 2019
# 4              Belgium                      1   80  1.150573e+07   1 Oct 2019
# 5               Brazil                     12    6  2.109599e+08   9 Jan 2020
# ..                 ...                    ...  ...           ...          ...
# 244           Tokelau                     NaN    –  1.400000e+03   1 Jul 2018
# 245       Vatican City                    NaN    –  7.990000e+02   1 Jul 2019
# 246    Cocos  Islands                     NaN    –  5.380000e+02  30 Jun 2018
# 247  Pitcairn Islands                     NaN    –  5.000000e+01   1 Jan 2019
# 248              World                    NaN  NaN  7.760127e+09   9 Jan 2020
#
#                                Source  % of World Population
# 1      National annual projection[30]                   0.01
# 2       National population clock[51]                   0.00
# 3    Quarterly provisional figure[92]                   0.00
# 4       Monthly National estimate[76]                   0.00
# 5        National population clock[8]                   0.03
# ..                                ...                    ...
# 244      National annual estimate[94]                   0.00
# 245                  UN projection[2]                   0.00
# 246            National estimate[197]                   0.00
# 247            National estimate[198]                   0.00
# 248                UN projection[199]                   1.00
#
# [248 rows x 7 columns]

# %%
#df_complete.info()
df_complete['number of billionaires'] = df_complete['number of billionaires'].astype(float)
df_complete=df_complete[df_complete['number of billionaires'].notnull()]
display(df_complete)
# Out:
#                  country  number of billionaires Rank   Population  \
# 1              Argentina                     3.0   31   44938712.0
# 2              Australia                    12.0   54   25578937.0
# 3                Austria                     2.0   97    8898457.0
# 4                Belgium                     1.0   80   11505732.0
# 5                 Brazil                    12.0    6  210959949.0
# ..                   ...                     ...  ...          ...
# 58  United Arab Emirates                     3.0   92    9770529.0
# 59        United Kingdom                    21.0   22   66435600.0
# 60         United States                   192.0    3  330557804.0
# 61             Venezuela                     1.0   44   32219521.0
# 62               Vietnam                     2.0   15   96208984.0
#
#            Date                              Source  % of World Population
# 1    1 Jul 2019      National annual projection[30]                   0.01
# 2    9 Jan 2020       National population clock[51]                   0.00
# 3    1 Oct 2019    Quarterly provisional figure[92]                   0.00
# 4    1 Oct 2019       Monthly National estimate[76]                   0.00
# 5    9 Jan 2020        National population clock[8]                   0.03
# ..          ...                                 ...                    ...
# 58   1 Jul 2019                    UN projection[2]                   0.00
# 59  30 Jun 2018        National annual estimate[22]                   0.01
# 60   9 Jan 2020        National population clock[5]                   0.04
# 61  30 Jun 2019      National annual projection[43]                   0.00
# 62   1 Apr 2019  Preliminary 2019 census result[16]                   0.01
#
# [62 rows x 7 columns]

# %%
types = df_complete['country']
x_coords = df_complete['number of billionaires']
y_coords = df_complete['% of World Population']
 
for i,type in enumerate(types):
    x = x_coords[i]
    y = y_coords[i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x+0.3, y+0.3, type, fontsize=9)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-750a88a74080> in <module>
#       4
#       5 for i,type in enumerate(types):
# ----> 6     x = x_coords[i]
#       7     y = y_coords[i]
#       8     plt.scatter(x, y, marker='x', color='red')
#
# ~/miniconda3/envs/jupyter_env/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# ~/miniconda3/envs/jupyter_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
y = df_complete['% of World Population']
z = df_complete['number of billionaires']
n = df_complete['country']
fig, ax = plt.subplots()
ax.scatter(z, y)
for i, txt in enumerate(n):
    ax.annotate(txt, (z[i], y[i]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-a9052cb64382> in <module>
#       5 ax.scatter(z, y)
#       6 for i, txt in enumerate(n):
# ----> 7     ax.annotate(txt, (z[i], y[i]))
#
# ~/miniconda3/envs/jupyter_env/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# ~/miniconda3/envs/jupyter_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
#plt.savefig('pic.png', dpi='figure')
#plt.savefig('pic.png', dpi=80)

# %%
#plt = df_complete.plot(kind='scatter',x='number of billionaires', y='% of World Population',color='red', figsize=(7,6))
#plt
