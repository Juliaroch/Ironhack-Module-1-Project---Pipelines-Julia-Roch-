# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
df_forbes = pd.read_csv('/Users/Julia/labs/Ironhack-Module-1-Project---Pipelines-Julia-Roch-/data/processed/processed_data.csv')
df_wikipedia = pd.read_csv('/Users/Julia/labs/Ironhack-Module-1-Project---Pipelines-Julia-Roch-/data/processed/processed_data_ws.csv')

# %%
df_complete = pd.merge(df_forbes, df_wikipedia, on='country', how='outer')

# %%
display(df_complete)
# Out:
#           id    lastName  age (years old)  Unnamed: 0_x gender  \
# 0     8760.0       BEZOS             54.0          52.0   None
# 1     5328.0  zUCKERBERg             33.0          56.0   None
# 2     1108.0     eLLISOn             73.0          61.0   None
# 3     5041.0        paGE             45.0          63.0   None
# 4     3569.0      wALTON             68.0          67.0   None
# ...      ...         ...              ...           ...    ...
# 2441     NaN         NaN              NaN           NaN    NaN
# 2442     NaN         NaN              NaN           NaN    NaN
# 2443     NaN         NaN              NaN           NaN    NaN
# 2444     NaN         NaN              NaN           NaN    NaN
# 2445     NaN         NaN              NaN           NaN    NaN
#
#                 country                                              image  \
# 0         United States  https://specials-images.forbesimg.com/imageser...
# ...

# %%
df_complete.plot(kind='scatter',x='country',y='',color='% of World Population')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7570aa72c4ae> in <module>
# ----> 1 df_complete.plot(kind='scatter',x='country',y='',color='% of World Population')
#       2 plt.show()
#
# ~/miniconda3/envs/jupyter_env/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# ~/miniconda3/envs/jupyter_env/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59                 ax = plt.gca()
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...
